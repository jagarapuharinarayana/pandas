# %%
import pandas as pd

# %%
df_battles=pd.read_csv(r"D:\got_dataset\battles.csv")

# %%
#it shows top five rows
df_battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
#it shows bottom 5 rows
df_battles.tail()
# Out:
#                            name  year  battle_number  \
# 33  Second Seige of Storm's End   300             34
# 34         Siege of Dragonstone   300             35
# 35            Siege of Riverrun   300             36
# 36           Siege of Raventree   300             37
# 37          Siege of Winterfell   300             38
#
#                attacker_king             defender_king attacker_1 attacker_2  \
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 35  Joffrey/Tommen Baratheon                Robb Stark  Lannister       Frey
# 36  Joffrey/Tommen Baratheon                Robb Stark    Bracken  Lannister
# 37         Stannis Baratheon  Joffrey/Tommen Baratheon  Baratheon   Karstark
#
#    attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 33        NaN        NaN  Baratheon  ...         0.0            0.0
# ...

# %%
#it gives row,column
df_battles.shape
# Out:
# (38, 25)

# %%
df_battles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
#it gives colummn in a data frame
df_battles.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
#view the region column
#first way
df_battles['region'].head()
# Out:
# 0    The Westerlands
# 1     The Riverlands
# 2     The Riverlands
# 3     The Riverlands
# 4     The Riverlands
# Name: region, dtype: object

# %%
# second way
df_battles.get('region').head()
# Out:
# 0    The Westerlands
# 1     The Riverlands
# 2     The Riverlands
# 3     The Riverlands
# 4     The Riverlands
# Name: region, dtype: object

# %%
type(df_battles['region'])
# Out:
# pandas.core.series.Series

# %%
# How many Battles were fought per region and sort them
df_battles['region'].value_counts()
# Out:
# region
# The Riverlands     17
# The North          10
# The Westerlands     3
# The Stormlands      3
# The Crownlands      2
# The Reach           2
# Beyond the Wall     1
# Name: count, dtype: int64

# %%
df_battles['region'].value_counts().plot(figsize=[2,2])
#default kind="line"
# Out:
# <Axes: xlabel='region'>

# %%
# plots are 'bar', 'barh', 'hist', 'pie', etc.
df_battles['region'].value_counts().plot(kind="pie",figsize=[3,3])
# Out:
# <Axes: ylabel='count'>

# %%
# How to select multiple columns
cols_to_select=['name','year']
df_battles[cols_to_select].head()
# Out:
#                             name  year
# 0     Battle of the Golden Tooth   298
# 1    Battle at the Mummer's Ford   298
# 2             Battle of Riverrun   298
# 3       Battle of the Green Fork   298
# 4  Battle of the Whispering Wood   298

# %%
cols_to_select=['name','year','region']
df_battles[cols_to_select].head()
# Out:
#                             name  year           region
# 0     Battle of the Golden Tooth   298  The Westerlands
# 1    Battle at the Mummer's Ford   298   The Riverlands
# 2             Battle of Riverrun   298   The Riverlands
# 3       Battle of the Green Fork   298   The Riverlands
# 4  Battle of the Whispering Wood   298   The Riverlands

# %%
type(df_battles[cols_to_select])
# Out:
# pandas.core.frame.DataFrame

# %%
df_battles[['name','region']].tail()
# Out:
#                            name          region
# 33  Second Seige of Storm's End  The Stormlands
# 34         Siege of Dragonstone  The Stormlands
# 35            Siege of Riverrun  The Riverlands
# 36           Siege of Raventree  The Riverlands
# 37          Siege of Winterfell       The North

# %%
#if one column is selected is Series
# if one or more column is selected is DataFrame
type(df_battles[['name','region']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Which year had most battles using pie chart
df_battles['year'].value_counts()
# Out:
# year
# 299    20
# 300    11
# 298     7
# Name: count, dtype: int64

# %%
df_battles['year'].value_counts().plot(kind='pie',figsize=[2,2],title="Which year had most battles using pie chart",autopct='%1.0f%%')
# Out:
# <Axes: title={'center': 'Which year had most battles using pie chart'}, ylabel='count'>

# %%
from matplotlib import pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Read excel or csv file and write to an excel or csv
import pandas as pd

# %%
df=pd.read_excel(r"Tme Table 2023 Odd sem (4).xlsx",sheet_name=None)

# %%
df.keys()
# Out:
# dict_keys(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'M.tech', 'Scholar name wise ', 'Scholar time table', 'Lab assistants', 'Subjects with code'])

# %%
df=pd.read_excel(r"Tme Table 2023 Odd sem (4).xlsx",sheet_name="Scholar name wise ")

# %%
df['Name of the Student']
# Out:
# 0                         Mr. Rajesh Yelchuri
# 1     Mr. Siginamsetty Venkata Phanidra Kumar
# 2                    Ms. Praneetha Surapaneni
# 3                           Mr. Ramdas Kapila
# 4                             Ms. Usha Kumari
# 5                            Ms. Arati Behera
# 6                      Ms. Rudra Krishnasrija
# 7                         Ms. Tokala Srilatha
# 8                          Ms. Gayathri Dhara
# 9                     Ms. Beri Surya Samantha
# 10                        Ms. Pavani Chitrapu
# 11           Ms. Yalamanchili Venkata Nandini
# 12                  POLAVARAPU BHAGYA LAKSHMI
# 13                           INAGANTI BHAVANA
# 14                        VENKAIAH CHOWDARY B
# 15                        USHASRI PEDDIBHOTLA
# 16                         SUBHAM KUMAR SAHOO
# 17                                  SURAYYA A
# 18                    SRINIVASARAO YARLAGADDA
# 19                               FAROOQ SHAIK
# ...

# %%
for i in df['Name of the Student']:
    print(i.replace("Mr.","").replace("Ms.","").strip())
        # print(i[4:])
    # print(i)
    # if "Mr. " in i or "Ms. " in i:
    #     print(i.split(".")[1])
# Out:
# Rajesh Yelchuri
# Siginamsetty Venkata Phanidra Kumar
# Praneetha Surapaneni
# Ramdas Kapila
# Usha Kumari
# Arati Behera
# Rudra Krishnasrija
# Tokala Srilatha
# Gayathri Dhara
# Beri Surya Samantha
# Pavani Chitrapu
# Yalamanchili Venkata Nandini
# POLAVARAPU BHAGYA LAKSHMI
# INAGANTI BHAVANA
# VENKAIAH CHOWDARY B
# USHASRI PEDDIBHOTLA
# SUBHAM KUMAR SAHOO
# SURAYYA A
# SRINIVASARAO YARLAGADDA
# FAROOQ SHAIK
# ANNAM NANDINI
# AVIRNENI VEDA SRI
# BHAGWATI SHARAN
# VENDRA DURGA RATNA KUMAR
# Subhra Prosun Paul
# SRUTHI. S
# Keerthi Garisa
# Madhusudhana Rao Baswani
# Mekala Sanjeev Kumar
# Ravi Bhargav
# A Rama Prasad Mathi
# Siva Rajesh Chiluveru
# Jitendra Shit
# Chitla Vinay Santhosh
# Cephas Iko Ojo Gabriel
# Jhansi Lakshmi Vigrahala
# Anupoju Tejaswi
# S Dharani Sabari
# Harinath Ankarboina
# Jasmini Kumari
# Mutupuri Shiva Shankar
# Madupuri Reddy Priya
# Shaik Vinsha
# Chanchal Biswas
# Subhasish Ghosh

# %%
for i in df['Name of the Student']:
    if "Mr. " in i or "Ms. " in i:
        print(i.replace("Mr. ","") or i.replace("Ms. ",""))
# Out:
# Rajesh Yelchuri
# Siginamsetty Venkata Phanidra Kumar
# Ms. Praneetha Surapaneni
# Ramdas Kapila
# Ms. Usha Kumari
# Ms. Arati Behera
# Ms. Rudra Krishnasrija
# Ms. Tokala Srilatha
# Ms. Gayathri Dhara
# Ms. Beri Surya Samantha
# Ms. Pavani Chitrapu
# Ms. Yalamanchili Venkata Nandini

# %%
df['Name of the Student']
# Out:
# 0                         Mr. Rajesh Yelchuri
# 1     Mr. Siginamsetty Venkata Phanidra Kumar
# 2                    Ms. Praneetha Surapaneni
# 3                           Mr. Ramdas Kapila
# 4                             Ms. Usha Kumari
# 5                            Ms. Arati Behera
# 6                      Ms. Rudra Krishnasrija
# 7                         Ms. Tokala Srilatha
# 8                          Ms. Gayathri Dhara
# 9                     Ms. Beri Surya Samantha
# 10                        Ms. Pavani Chitrapu
# 11           Ms. Yalamanchili Venkata Nandini
# 12                  POLAVARAPU BHAGYA LAKSHMI
# 13                           INAGANTI BHAVANA
# 14                        VENKAIAH CHOWDARY B
# 15                        USHASRI PEDDIBHOTLA
# 16                         SUBHAM KUMAR SAHOO
# 17                                  SURAYYA A
# 18                    SRINIVASARAO YARLAGADDA
# 19                               FAROOQ SHAIK
# ...

# %%
df=df.dropna()

# %%
df.reset_index(inplace=True)

# %%
df.drop('S.No',axis=1)
df['index']='S.No'

# %%
df.rename(columns={"index":"S.No"},inplace=True)

# %%
# drop a column
df.drop('S.No',axis=1).head(2)
# Out:
#                        Name of the Student Name of Research Supervisor  \
# 0                      Mr. Rajesh Yelchuri     Dr. Jatindra Kumar Dash
# 1  Mr. Siginamsetty Venkata Phanidra Kumar              Dr. Ashu Abdul
#
#          Unnamed: 3        Unnamed: 4        Unnamed: 5
# 0  Mon 2 hours W101  Thu 2 hours W102  Wed 2 Hours S412
# 1  Wed 2 hours W403  Tue 2 hours W102  Thu 2 Hours W102

# %%
df.rename(columns= {"Unnamed: 3":"Lab - 1","Unnamed: 4":"Lab - 2","Unnamed: 5":"Lab - 3"},inplace=True)

# %%
df.drop("S.No",axis=1,inplace=True)

# %%
df.tail(1)
# Out:
#    Name of the Student Name of Research Supervisor           Lab - 1  \
# 41        Shaik Vinsha                 Dr.Priyanka  Tue 2 Hours S603
#
#              Lab - 2           Lab - 3
# 41  Fri 2 Hours W412  Thu 2 Hours W601

# %%
df
# Out:
#                         Name of the Student Name of Research Supervisor  \
# 0                       Mr. Rajesh Yelchuri     Dr. Jatindra Kumar Dash
# 1   Mr. Siginamsetty Venkata Phanidra Kumar              Dr. Ashu Abdul
# 2                  Ms. Praneetha Surapaneni             Dr. B Sriramulu
# 3                         Mr. Ramdas Kapila               Dr. Sumalatha
# 4                           Ms. Usha Kumari           Dr. Shuvendu Rana
# 5                          Ms. Arati Behera      Dr. Kshirasagara Sahoo
# 6                    Ms. Rudra Krishnasrija       Dr. Amit Kumar Mandal
# 7                       Ms. Tokala Srilatha   Dr. Murali Krishna Enduri
# 8                        Ms. Gayathri Dhara         Dr. Ravi Kant Kumar
# 9                   Ms. Beri Surya Samantha             Dr. Nitul Dutta
# 10                      Ms. Pavani Chitrapu  Dr. Hemantha Kumar Kalluri
# 11         Ms. Yalamanchili Venkata Nandini  Dr. Jaya Lakshmi Tangirala
# ...

# %%
df.columns
# Define a custom sorting order for days
# Out:
# Index(['Name of the Student', 'Name of Research Supervisor', 'Lab - 1',
#        'Lab - 2', 'Lab - 3'],
#       dtype='object')

# %%
days_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

# %%
sorted_df= df.sort_values(by='Lab - 1')

# %%
for i in range(len(df)):
    print(df.loc[i].sort_values(by=df['Lab - 1'][i][:3]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[349], line 2
#       1 for i in range(len(df)):
# ----> 2     print(df.loc[i].sort_values(by=df['Lab - 1'][i][:3]))
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
df['Lab - 1'][0][:3]
# Out:
# 'Mon'

# %%
df.loc[2].sort_values(by=df['Lab - 1'][2][:3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[350], line 1
# ----> 1 df.loc[2].sort_values(by=df['Lab - 1'][2][:3])
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Lab - 1': ['Mon 2 hours W101', 'Wed 2 hours W403', 'Mon 2 hours W106'],
    'Lab - 2': ['Thu 2 hours W102', 'Tue 2 hours W102', 'Thu 2 hours S412']
}

df = pd.DataFrame(data)

# Specify the custom sorting order for days
days_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

# Define a function to extract the day from a lab entry
def extract_day(entry):
    return entry.split()[0]

# Sort the Series based on the custom day order
sorted_series = df.loc[1].sort_values(key=lambda x: x.map(extract_day, na_action='ignore'))

# Print the sorted Series
print(sorted_series)
# Out:
# Lab - 2    Tue 2 hours W102
# Lab - 1    Wed 2 hours W403
# Name: 1, dtype: object

# %%
import pandas as pd
df

# Specify the custom sorting order for days
days_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

# Define a function to extract the day from a lab entry
def extract_day(entry):
    return entry.split()[0]
for i in range(len(df)):
# Sort the Series based on the custom day order
    sorted_series = df.loc[i].sort_values(key=lambda x: x.map(extract_day, na_action='ignore'))

# Print the sorted Series
    print(sorted_series)
# Out:
# Name of Research Supervisor    Dr. Jatindra Kumar Dash
# Lab - 1                               Mon 2 hours W101
# Name of the Student                Mr. Rajesh Yelchuri
# Lab - 2                               Thu 2 hours W102
# Lab - 3                               Wed 2 Hours S412
# Name: 0, dtype: object
# Name of Research Supervisor                             Dr. Ashu Abdul
# Name of the Student            Mr. Siginamsetty Venkata Phanidra Kumar
# Lab - 3                                               Thu 2 Hours W102
# Lab - 2                                               Tue 2 hours W102
# Lab - 1                                               Wed 2 hours W403
# Name: 1, dtype: object
# Name of Research Supervisor             Dr. B Sriramulu
# Lab - 3                                Fri 2 Hours W604
# Lab - 1                                Mon 2 hours W106
# Name of the Student            Ms. Praneetha Surapaneni
# Lab - 2                                Thu 2 hours S412
# ...

# %%
# Out:
#             Lab - 1           Lab - 2
# 0  Mon 2 hours W101  Thu 2 hours W102
# 1  Wed 2 hours W403  Tue 2 hours W102
# 2  Mon 2 hours W106  Thu 2 hours S412

# %%
for i in range(len(df)):
    print(df.iloc[i][0:][2][:3]=="Mon")
# df
# Out:
# True
# False
# True
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
df['Name of the Student']
# Out:
# 0                         Mr. Rajesh Yelchuri
# 1     Mr. Siginamsetty Venkata Phanidra Kumar
# 2                    Ms. Praneetha Surapaneni
# 3                           Mr. Ramdas Kapila
# 4                             Ms. Usha Kumari
# 5                            Ms. Arati Behera
# 6                      Ms. Rudra Krishnasrija
# 7                         Ms. Tokala Srilatha
# 8                          Ms. Gayathri Dhara
# 9                     Ms. Beri Surya Samantha
# 10                        Ms. Pavani Chitrapu
# 11           Ms. Yalamanchili Venkata Nandini
# 12                  POLAVARAPU BHAGYA LAKSHMI
# 13                        VENKAIAH CHOWDARY B
# 14                        USHASRI PEDDIBHOTLA
# 15                         SUBHAM KUMAR SAHOO
# 16                                  SURAYYA A
# 17                    SRINIVASARAO YARLAGADDA
# 18                               FAROOQ SHAIK
# 19                              ANNAM NANDINI
# ...

# %%
for i in range(len(df)):
    print(df.iloc[i][2:].values)
    
    break
# Out:
# ['Mon 2 hours W101' 'Thu 2 hours W102' 'Wed 2 Hours S412']

# %%
[i.lower() for i in df.iloc[0][3:].values]
# Out:
# ['mon 2 hours w101', 'wed 2 hours s412', 'thu 2 hours w102']

# %%
days = ['mon', 'tue', 'wed', 'thu', 'fri']
days
# Out:
# ['mon', 'tue', 'wed', 'thu', 'fri']

# %%
sorted([i.lower() for i in df.iloc[0][3:].values], key=lambda x: days.index(x.split()[0]))
# Out:
# ['mon 2 hours w101', 'wed 2 hours s412', 'thu 2 hours w102']

# %%
lambda x: days.index(x.split()[0])
# Out:
# <function __main__.<lambda>(x)>

# %%
df.to_excel("Scholars_day_wise.xlsx")

# %%
import pandas as pd
df=pd.read_excel(r"Scholars_day_wise.xlsx")
D = []
for i in range(len(df)):
  df.iloc[i][3:].values.sort()
  days = ['mon', 'tue', 'wed', 'thu', 'fri']
  sorted_lst = sorted([i.lower() for i in df.iloc[i][3:].values], key=lambda x: days.index(x.split()[0]))
  print(sorted_lst)
  D.append(sorted_lst)
# Out:
# ['mon 2 hours w101', 'wed 2 hours s412', 'thu 2 hours w102']
# ['tue 2 hours w102', 'wed 2 hours w403', 'thu 2 hours s613']
# ['mon 2 hours w106', 'thu 2 hours s412', 'fri 2 hours w604']
# ['mon 2 hours w601', 'tue 2 hours w106', 'tue 2 hours w101']
# ['tue 2 hours w602', 'thu 2 hours w101', 'thu 2 hours w102']
# ['tue 2 hours s202', 'tue 2 hours w604', 'wed 2 hours w601']
# ['wed 2 hours s202', 'thu 2 hours w603', 'fri 2 hours s610']
# ['mon 2 hours w603', 'thu 2 hours w602', 'fri 2 hours w102']
# ['tue 2 hours w603', 'wed 2 hours w604', 'wed 2 hours s613']
# ['tue 2 hours w601', 'thu 2 hours w604', 'fri 2 hours s412']
# ['tue 2 hours s610', 'tue 2 hours w604', 'fri 2 hours w604']
# ['tue 2 hours w601', 'wed 2 hours w602', 'fri 2 hours w106']
# ['mon 2 hours w106', 'wed 2 hours s412', 'thu 2 hours s202']
# ['tue 2 hours w403', 'wed 2 hours s603', 'fri 2 hours w403']
# ['tue 2 hours w403', 'wed 2 hours s611', 'thu 2 hours s202']
# ...

# %%
df[['Lab - 1', 'Lab - 2', 'Lab - 3']] = D

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name of the Student', 'Name of Research Supervisor',
#        'Lab - 1', 'Lab - 2', 'Lab - 3'],
#       dtype='object')

# %%
df
# Out:
#     Unnamed: 0                      Name of the Student  \
# 0            0                      Mr. Rajesh Yelchuri
# 1            1  Mr. Siginamsetty Venkata Phanidra Kumar
# 2            2                 Ms. Praneetha Surapaneni
# 3            3                        Mr. Ramdas Kapila
# 4            4                          Ms. Usha Kumari
# 5            5                         Ms. Arati Behera
# 6            6                   Ms. Rudra Krishnasrija
# 7            7                      Ms. Tokala Srilatha
# 8            8                       Ms. Gayathri Dhara
# 9            9                  Ms. Beri Surya Samantha
# 10          10                      Ms. Pavani Chitrapu
# 11          11         Ms. Yalamanchili Venkata Nandini
# 12          12                POLAVARAPU BHAGYA LAKSHMI
# 13          13                      VENKAIAH CHOWDARY B
# 14          14                      USHASRI PEDDIBHOTLA
# 15          15                       SUBHAM KUMAR SAHOO
# ...

# %%
df.to_excel("Updated_scholar data.xlsx")

# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_excel(r"Updated_scholar data.xlsx")

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#                        Name of the Student Name of Research Supervisor  \
# 0                      Mr. Rajesh Yelchuri     Dr. Jatindra Kumar Dash
# 1  Mr. Siginamsetty Venkata Phanidra Kumar              Dr. Ashu Abdul
#
#             Lab - 1           Lab - 2           Lab - 3
# 0  mon 2 hours w101  wed 2 hours s412  thu 2 hours w102
# 1  tue 2 hours w102  wed 2 hours w403  thu 2 hours s613

# %%
data = ["Mon","Tues","Wed","Thu","Fri","Sat","Sun"]

# %%
[i.lower() for i in data]
# Out:
# ['mon', 'tues', 'wed', 'thu', 'fri', 'sat', 'sun']

# %%
people = [
    {"name": "Alice", "age": 25},
    {"name": "Bob", "age": 30},
    {"name": "Charlie", "age": 22},
    {"name": "David", "age": 35},
]

# %%
sorted_people = sorted(people, key=lambda x: x["name"], reverse=False)
sorted_people
# Out:
# [{'name': 'Alice', 'age': 25},
#  {'name': 'Bob', 'age': 30},
#  {'name': 'Charlie', 'age': 22},
#  {'name': 'David', 'age': 35}]

# %%
names=['Charlie','David','Bob','Alice']

# %%
data = [
    {'name': 'Alice', 'age': 25},
    {'name': 'Bob', 'age': 30},
    {'name': 'Charlie', 'age': 22},
    {'name': 'David', 'age': 35}
]

names = ['Charlie', 'David', 'Bob', 'Alice']

sorted_data = sorted(data, key=lambda x: names.index(x['name']))

print(sorted_data)
# Out:
# [{'name': 'Charlie', 'age': 22}, {'name': 'David', 'age': 35}, {'name': 'Bob', 'age': 30}, {'name': 'Alice', 'age': 25}]

# %%
# sorted([i for i in sorted_people.values()], key=lambda x: names.index(x.split()[0]))

# %%
for i in sorted_people[0]:
   for j in i:
       print(sorted_people[0])
# Out:
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 25}
