# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
a=["Mr. hari","Mr.Phani    "]

# %%
a
# Out:
# ['Mr. hari', 'Mr.Phani    ']

# %%
for i in a:
    print(i.split(".")[1].strip())
# Out:
# hari
# Phani

# %%
a
# Out:
# ['Mr. hari', 'Mr.Phani    ']

# %%
a.append([list(range(1,5))])

# %%
a
# Out:
# ['Mr. hari', 'Mr.Phani    ', [...], [[1, 2, 3, 4]]]

# %%
a[-1][0][-2:]
# Out:
# [3, 4]

# %%
import seabron as
# Out:
#   Input In [31]
#     import seabron as
#                       ^
# SyntaxError: invalid syntax

# %%
for i in a:
    print(a[-1][0][-2:])
# Out:
# [3, 4]
# [3, 4]
# [3, 4]
# [3, 4]

# %%
a
# Out:
# ['Mr. hari', 'Mr.Phani    ', [...], [[1, 2, 3, 4]]]

# %%
for i in a:
    print(i[0])
# Out:
# Mr
# Mr
# ['Mr. hari', 'Mr.Phani    ']
# [[1, 2, 3, 4]]

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace  = True)

# %%
df.reset_index(drop = True,inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 177          872         1       1
# 178          873         0       1
# 179          880         1       1
# 180          888         1       1
# 181          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].describe()
# Out:
# count    181.000000
# mean      35.969613
# std       15.450383
# min        1.000000
# 25%       24.000000
# 50%       36.000000
# 75%       48.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age_category'] = pd.cut(df['Age'],[1,30,50,110],labels=["Young","Middle","Old"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 177          872         1       1
# 178          873         0       1
# 179          880         1       1
# 180          888         1       1
# 181          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a = {"female":1,"male":2}
df["Gender"] = df['Sex'].map(a)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 177          872         1       1
# 178          873         0       1
# 179          880         1       1
# 180          888         1       1
# 181          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# for i in df['Cabin']:
#     print(i.split()[0][0],i.split()[0][1:])
# Out:
# C 85
# C 123
# E 46
# G 6
# C 103
# D 56
# A 6
# C 23
# D 33
# B 30
# C 83
# F 33
# F
# C 23
# E 31
# A 5
# D 10
# D 26
# C 110
# B 58
# E 101
# D 26
# D 47
# C 123
# B 86
# F 2
# C 2
# B 19
# A 7
# C 49
# F 4
# F 2
# B 4
# B 80
# G 6
# A 31
# D 36
# D 15
# C 93
# C 83
# C 78
# D 35
# G 6
# C 87
# B 77
# E 67
# B 94
# C 125
# C 99
# C 118
# D 7
# B 49
# D
# C 22
# B 58
# E 36
# C 54
# B 57
# C 7
# E 34
# C 32
# D
# B 18
# C 124
# C 91
# C 2
# E 40
# T
# F 2
# C 23
# F 33
# E 33
# D 37
# B 35
# E 50
# C 82
# B 96
# D 36
# G 6
# C 78
# E 10
# C 52
# E 44
# B 96
# C 23
# A 34
# C 104
# C 111
# C 92
# E 38
# E 12
# E 63
# D
# B 49
# C 93
# B 37
# C 30
# D 20
# C 22
# B 79
# C 65
# E 25
# D 46
# F 33
# B 73
# B 18
# B 38
# B 39
# B 22
# C 86
# C 70
# A 16
# E 67
# C 101
# E 25
# E 44
# C 68
# A 10
# E 68
# B 41
# D 20
# A 20
# C 125
# F 4
# D 19
# D 50
# D 9
# A 23
# B 50
# B 35
# D 33
# A 26
# D 48
# E 58
# B 71
# B 51
# D 49
# B 5
# B 20
# C 68
# F
# C 62
# E 24
# E 24
# C 90
# C 126
# ...

# %%
def age(n):
    if n > 1 and n<= 30:
        return "Young"
    elif n>30 and n<=50:
        return "Middle"
    else:
        return "Old"

# %%
df["Age_call"] = df['Age'].apply(lambda n: age(n))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 177          872         1       1
# 178          873         0       1
# 179          880         1       1
# 180          888         1       1
# 181          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...
